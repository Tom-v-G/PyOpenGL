# %% [markdown]
# # Terrain Generation

# %% [markdown]
# ## Perlin Noise

# %%
import matplotlib.pyplot as plt
import numpy as np
from itertools import chain

# %%
data_type_unitvec = np.dtype({
    "names": ["x", "z"],
    "formats": [np.float32, np.float32],
    "offsets": [0, 4],
    "itemsize": 8
})

arr = np.zeros(shape=(16, 16), dtype=data_type_unitvec)

unit_vecs = np.array([np.random.rand(1,2) for i in range(16*16)], dtype=data_type_unitvec)


print(unit_vecs)
# Out:
# [(0.42618847, 0.42618847) (0.39402485, 0.39402485)
#  (0.54650897, 0.54650897) (0.25543123, 0.25543123)
#  (0.6459586 , 0.6459586 ) (0.6921353 , 0.6921353 )
#  (0.0953969 , 0.0953969 ) (0.10522249, 0.10522249)
#  (0.27598763, 0.27598763) (0.10252579, 0.10252579)
#  (0.11234795, 0.11234795) (0.5797171 , 0.5797171 )
#  (0.11523519, 0.11523519) (0.39984277, 0.39984277)
#  (0.33724332, 0.33724332) (0.28753123, 0.28753123)
#  (0.57584333, 0.57584333) (0.6509292 , 0.6509292 )
#  (0.18739179, 0.18739179) (0.5176617 , 0.5176617 )
#  (0.19627458, 0.19627458) (0.29294887, 0.29294887)
#  (0.25651976, 0.25651976) (0.06054757, 0.06054757)
#  (0.79851407, 0.79851407) (0.80996233, 0.80996233)
#  (0.25395823, 0.25395823) (0.38782027, 0.38782027)
#  (0.41658255, 0.41658255) (0.03032862, 0.03032862)
#  (0.21355581, 0.21355581) (0.16860427, 0.16860427)
#  (0.84823954, 0.84823954) (0.18788025, 0.18788025)
#  (0.3177258 , 0.3177258 ) (0.80786186, 0.80786186)
# ...
